# %% [markdown]
# <a href="https://colab.research.google.com/github/smalvar/CalculadoraAluguel-Awari-NOV-/blob/main/1-%20Web%20scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.vivareal.com.br/venda/sp/sao-paulo/apartamento_residencial/'

# %%
c = requests.get(url).content
soup = BeautifulSoup(c)
# Out:
# /usr/lib/python3/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
aluguel_tag = soup.find_all('div', {'class':'property-card__price js-property-card-prices js-property-card__price-small'}) 
len(aluguel_tag)
# Out:
# 36

# %%
paginas = ['']
for i in range(2,200):
    a = '?pagina='+str(i)
    print(a)
    paginas.append(a)
# Out:
# ?pagina=2
# ?pagina=3
# ?pagina=4
# ?pagina=5
# ?pagina=6
# ?pagina=7
# ?pagina=8
# ?pagina=9
# ?pagina=10
# ?pagina=11
# ?pagina=12
# ?pagina=13
# ?pagina=14
# ?pagina=15
# ?pagina=16
# ?pagina=17
# ?pagina=18
# ?pagina=19
# ?pagina=20
# ?pagina=21
# ?pagina=22
# ?pagina=23
# ?pagina=24
# ?pagina=25
# ?pagina=26
# ?pagina=27
# ?pagina=28
# ?pagina=29
# ?pagina=30
# ?pagina=31
# ?pagina=32
# ?pagina=33
# ?pagina=34
# ?pagina=35
# ?pagina=36
# ?pagina=37
# ?pagina=38
# ?pagina=39
# ?pagina=40
# ?pagina=41
# ?pagina=42
# ?pagina=43
# ?pagina=44
# ?pagina=45
# ?pagina=46
# ?pagina=47
# ?pagina=48
# ?pagina=49
# ?pagina=50
# ?pagina=51
# ?pagina=52
# ?pagina=53
# ?pagina=54
# ?pagina=55
# ?pagina=56
# ?pagina=57
# ?pagina=58
# ?pagina=59
# ?pagina=60
# ?pagina=61
# ?pagina=62
# ?pagina=63
# ?pagina=64
# ?pagina=65
# ?pagina=66
# ?pagina=67
# ?pagina=68
# ?pagina=69
# ?pagina=70
# ?pagina=71
# ?pagina=72
# ?pagina=73
# ?pagina=74
# ?pagina=75
# ?pagina=76
# ?pagina=77
# ?pagina=78
# ?pagina=79
# ?pagina=80
# ?pagina=81
# ?pagina=82
# ?pagina=83
# ?pagina=84
# ?pagina=85
# ?pagina=86
# ?pagina=87
# ?pagina=88
# ?pagina=89
# ?pagina=90
# ?pagina=91
# ?pagina=92
# ?pagina=93
# ?pagina=94
# ?pagina=95
# ?pagina=96
# ?pagina=97
# ?pagina=98
# ?pagina=99
# ?pagina=100
# ?pagina=101
# ?pagina=102
# ?pagina=103
# ?pagina=104
# ?pagina=105
# ?pagina=106
# ?pagina=107
# ?pagina=108
# ?pagina=109
# ?pagina=110
# ?pagina=111
# ?pagina=112
# ?pagina=113
# ?pagina=114
# ?pagina=115
# ?pagina=116
# ?pagina=117
# ?pagina=118
# ?pagina=119
# ?pagina=120
# ?pagina=121
# ?pagina=122
# ?pagina=123
# ?pagina=124
# ?pagina=125
# ?pagina=126
# ?pagina=127
# ?pagina=128
# ?pagina=129
# ?pagina=130
# ?pagina=131
# ?pagina=132
# ?pagina=133
# ?pagina=134
# ?pagina=135
# ?pagina=136
# ?pagina=137
# ?pagina=138
# ?pagina=139
# ?pagina=140
# ?pagina=141
# ?pagina=142
# ?pagina=143
# ?pagina=144
# ?pagina=145
# ?pagina=146
# ?pagina=147
# ?pagina=148
# ?pagina=149
# ?pagina=150
# ?pagina=151
# ?pagina=152
# ?pagina=153
# ?pagina=154
# ?pagina=155
# ?pagina=156
# ?pagina=157
# ?pagina=158
# ?pagina=159
# ?pagina=160
# ?pagina=161
# ?pagina=162
# ?pagina=163
# ?pagina=164
# ?pagina=165
# ?pagina=166
# ?pagina=167
# ?pagina=168
# ?pagina=169
# ?pagina=170
# ?pagina=171
# ?pagina=172
# ?pagina=173
# ?pagina=174
# ?pagina=175
# ?pagina=176
# ?pagina=177
# ?pagina=178
# ?pagina=179
# ?pagina=180
# ?pagina=181
# ?pagina=182
# ?pagina=183
# ?pagina=184
# ?pagina=185
# ?pagina=186
# ?pagina=187
# ?pagina=188
# ?pagina=189
# ?pagina=190
# ?pagina=191
# ?pagina=192
# ?pagina=193
# ?pagina=194
# ?pagina=195
# ?pagina=196
# ?pagina=197
# ?pagina=198
# ?pagina=199

# %%
paginas
# Out:
# ['',
#  '?pagina=2',
#  '?pagina=3',
#  '?pagina=4',
#  '?pagina=5',
#  '?pagina=6',
#  '?pagina=7',
#  '?pagina=8',
#  '?pagina=9',
#  '?pagina=10',
#  '?pagina=11',
#  '?pagina=12',
#  '?pagina=13',
#  '?pagina=14',
#  '?pagina=15',
#  '?pagina=16',
#  '?pagina=17',
#  '?pagina=18',
#  '?pagina=19',
#  '?pagina=20',
#  '?pagina=21',
#  '?pagina=22',
#  '?pagina=23',
#  '?pagina=24',
#  '?pagina=25',
#  '?pagina=26',
#  '?pagina=27',
#  '?pagina=28',
#  '?pagina=29',
#  '?pagina=30',
#  '?pagina=31',
#  '?pagina=32',
#  '?pagina=33',
#  '?pagina=34',
#  '?pagina=35',
#  '?pagina=36',
#  '?pagina=37',
#  '?pagina=38',
#  '?pagina=39',
#  '?pagina=40',
#  '?pagina=41',
#  '?pagina=42',
#  '?pagina=43',
#  '?pagina=44',
#  '?pagina=45',
#  '?pagina=46',
#  '?pagina=47',
#  '?pagina=48',
#  '?pagina=49',
#  '?pagina=50',
#  '?pagina=51',
#  '?pagina=52',
#  '?pagina=53',
#  '?pagina=54',
#  '?pagina=55',
#  '?pagina=56',
#  '?pagina=57',
#  '?pagina=58',
#  '?pagina=59',
#  '?pagina=60',
#  '?pagina=61',
#  '?pagina=62',
#  '?pagina=63',
#  '?pagina=64',
#  '?pagina=65',
#  '?pagina=66',
#  '?pagina=67',
#  '?pagina=68',
#  '?pagina=69',
#  '?pagina=70',
#  '?pagina=71',
#  '?pagina=72',
#  '?pagina=73',
#  '?pagina=74',
#  '?pagina=75',
#  '?pagina=76',
#  '?pagina=77',
#  '?pagina=78',
#  '?pagina=79',
#  '?pagina=80',
#  '?pagina=81',
#  '?pagina=82',
#  '?pagina=83',
#  '?pagina=84',
#  '?pagina=85',
#  '?pagina=86',
#  '?pagina=87',
#  '?pagina=88',
#  '?pagina=89',
#  '?pagina=90',
#  '?pagina=91',
#  '?pagina=92',
#  '?pagina=93',
#  '?pagina=94',
#  '?pagina=95',
#  '?pagina=96',
#  '?pagina=97',
#  '?pagina=98',
#  '?pagina=99',
#  '?pagina=100',
#  '?pagina=101',
#  '?pagina=102',
#  '?pagina=103',
#  '?pagina=104',
#  '?pagina=105',
#  '?pagina=106',
#  '?pagina=107',
#  '?pagina=108',
#  '?pagina=109',
#  '?pagina=110',
#  '?pagina=111',
#  '?pagina=112',
#  '?pagina=113',
#  '?pagina=114',
#  '?pagina=115',
#  '?pagina=116',
#  '?pagina=117',
#  '?pagina=118',
#  '?pagina=119',
#  '?pagina=120',
#  '?pagina=121',
#  '?pagina=122',
#  '?pagina=123',
#  '?pagina=124',
#  '?pagina=125',
#  '?pagina=126',
#  '?pagina=127',
#  '?pagina=128',
#  '?pagina=129',
#  '?pagina=130',
#  '?pagina=131',
#  '?pagina=132',
#  '?pagina=133',
#  '?pagina=134',
#  '?pagina=135',
#  '?pagina=136',
#  '?pagina=137',
#  '?pagina=138',
#  '?pagina=139',
#  '?pagina=140',
#  '?pagina=141',
#  '?pagina=142',
#  '?pagina=143',
#  '?pagina=144',
#  '?pagina=145',
#  '?pagina=146',
#  '?pagina=147',
#  '?pagina=148',
#  '?pagina=149',
#  '?pagina=150',
#  '?pagina=151',
#  '?pagina=152',
#  '?pagina=153',
#  '?pagina=154',
#  '?pagina=155',
#  '?pagina=156',
#  '?pagina=157',
#  '?pagina=158',
#  '?pagina=159',
#  '?pagina=160',
#  '?pagina=161',
#  '?pagina=162',
#  '?pagina=163',
#  '?pagina=164',
#  '?pagina=165',
#  '?pagina=166',
#  '?pagina=167',
#  '?pagina=168',
#  '?pagina=169',
#  '?pagina=170',
#  '?pagina=171',
#  '?pagina=172',
#  '?pagina=173',
#  '?pagina=174',
#  '?pagina=175',
#  '?pagina=176',
#  '?pagina=177',
#  '?pagina=178',
#  '?pagina=179',
#  '?pagina=180',
#  '?pagina=181',
#  '?pagina=182',
#  '?pagina=183',
#  '?pagina=184',
#  '?pagina=185',
#  '?pagina=186',
#  '?pagina=187',
#  '?pagina=188',
#  '?pagina=189',
#  '?pagina=190',
#  '?pagina=191',
#  '?pagina=192',
#  '?pagina=193',
#  '?pagina=194',
#  '?pagina=195',
#  '?pagina=196',
#  '?pagina=197',
#  '?pagina=198',
#  '?pagina=199']

# %%
import pandas as pd
def converter_df(aluguel_lista,quartos_lista,endereco_lista,banheiro_lista,vaga_lista,area_lista):
    data = {'aluguel':aluguel_lista,
           'quartos':quartos_lista,
           'endereco':endereco_lista,
           'banheiro':banheiro_lista,
            'vaga':vaga_lista,
            'area':area_lista}
    df = pd.DataFrame(data)
    return df

# %%
def scrap(url):
    c = requests.get(url).content
    soup = BeautifulSoup(c)
    
    aluguel_tag = soup.find_all('div', {'class':'property-card__price js-property-card-prices js-property-card__price-small'}) 
    aluguel_lista = [p.text for p in aluguel_tag] 
    #print(len(aluguel_lista)) 
    
    quartos_tag = soup.find_all('li', {'class': 'property-card__detail-item property-card__detail-room js-property-detail-rooms'}) 
    quartos_lista = [en.text for en in quartos_tag] 
    #print(len(quartos_lista)) 
    
    endereco_tag = soup.find_all('span', {'class': 'property-card__address'}) 
    endereco_lista = [fg.text for fg in endereco_tag] 
    #print(len(endereco_lista)) 
    
    banheiro_tag = soup.find_all('li', {'class': 'property-card__detail-item property-card__detail-bathroom js-property-detail-bathroom'}) 
    banheiro_lista = [yp.text for yp in banheiro_tag] 
    #print(len(banheiro_lista))

    vaga_tag = soup.find_all('li', {'class': 'property-card__detail-item property-card__detail-garage js-property-detail-garages'}) 
    vaga_lista = [yp.text for yp in vaga_tag] 

    area_tag = soup.find_all('li', {'class': 'property-card__detail-item property-card__detail-area'}) 
    area_lista = [yp.text for yp in area_tag] 


    ### Vamos ter criar uma função para transformar listas em df
    df=converter_df(aluguel_lista,quartos_lista,endereco_lista,banheiro_lista,vaga_lista,area_lista)
    
    return df

# %%
paginas
# Out:
# ['',
#  '?pagina=2',
#  '?pagina=3',
#  '?pagina=4',
#  '?pagina=5',
#  '?pagina=6',
#  '?pagina=7',
#  '?pagina=8',
#  '?pagina=9',
#  '?pagina=10',
#  '?pagina=11',
#  '?pagina=12',
#  '?pagina=13',
#  '?pagina=14',
#  '?pagina=15',
#  '?pagina=16',
#  '?pagina=17',
#  '?pagina=18',
#  '?pagina=19',
#  '?pagina=20',
#  '?pagina=21',
#  '?pagina=22',
#  '?pagina=23',
#  '?pagina=24',
#  '?pagina=25',
#  '?pagina=26',
#  '?pagina=27',
#  '?pagina=28',
#  '?pagina=29',
#  '?pagina=30',
#  '?pagina=31',
#  '?pagina=32',
#  '?pagina=33',
#  '?pagina=34',
#  '?pagina=35',
#  '?pagina=36',
#  '?pagina=37',
#  '?pagina=38',
#  '?pagina=39',
#  '?pagina=40',
#  '?pagina=41',
#  '?pagina=42',
#  '?pagina=43',
#  '?pagina=44',
#  '?pagina=45',
#  '?pagina=46',
#  '?pagina=47',
#  '?pagina=48',
#  '?pagina=49',
#  '?pagina=50',
#  '?pagina=51',
#  '?pagina=52',
#  '?pagina=53',
#  '?pagina=54',
#  '?pagina=55',
#  '?pagina=56',
#  '?pagina=57',
#  '?pagina=58',
#  '?pagina=59',
#  '?pagina=60',
#  '?pagina=61',
#  '?pagina=62',
#  '?pagina=63',
#  '?pagina=64',
#  '?pagina=65',
#  '?pagina=66',
#  '?pagina=67',
#  '?pagina=68',
#  '?pagina=69',
#  '?pagina=70',
#  '?pagina=71',
#  '?pagina=72',
#  '?pagina=73',
#  '?pagina=74',
#  '?pagina=75',
#  '?pagina=76',
#  '?pagina=77',
#  '?pagina=78',
#  '?pagina=79',
#  '?pagina=80',
#  '?pagina=81',
#  '?pagina=82',
#  '?pagina=83',
#  '?pagina=84',
#  '?pagina=85',
#  '?pagina=86',
#  '?pagina=87',
#  '?pagina=88',
#  '?pagina=89',
#  '?pagina=90',
#  '?pagina=91',
#  '?pagina=92',
#  '?pagina=93',
#  '?pagina=94',
#  '?pagina=95',
#  '?pagina=96',
#  '?pagina=97',
#  '?pagina=98',
#  '?pagina=99',
#  '?pagina=100',
#  '?pagina=101',
#  '?pagina=102',
#  '?pagina=103',
#  '?pagina=104',
#  '?pagina=105',
#  '?pagina=106',
#  '?pagina=107',
#  '?pagina=108',
#  '?pagina=109',
#  '?pagina=110',
#  '?pagina=111',
#  '?pagina=112',
#  '?pagina=113',
#  '?pagina=114',
#  '?pagina=115',
#  '?pagina=116',
#  '?pagina=117',
#  '?pagina=118',
#  '?pagina=119',
#  '?pagina=120',
#  '?pagina=121',
#  '?pagina=122',
#  '?pagina=123',
#  '?pagina=124',
#  '?pagina=125',
#  '?pagina=126',
#  '?pagina=127',
#  '?pagina=128',
#  '?pagina=129',
#  '?pagina=130',
#  '?pagina=131',
#  '?pagina=132',
#  '?pagina=133',
#  '?pagina=134',
#  '?pagina=135',
#  '?pagina=136',
#  '?pagina=137',
#  '?pagina=138',
#  '?pagina=139',
#  '?pagina=140',
#  '?pagina=141',
#  '?pagina=142',
#  '?pagina=143',
#  '?pagina=144',
#  '?pagina=145',
#  '?pagina=146',
#  '?pagina=147',
#  '?pagina=148',
#  '?pagina=149',
#  '?pagina=150',
#  '?pagina=151',
#  '?pagina=152',
#  '?pagina=153',
#  '?pagina=154',
#  '?pagina=155',
#  '?pagina=156',
#  '?pagina=157',
#  '?pagina=158',
#  '?pagina=159',
#  '?pagina=160',
#  '?pagina=161',
#  '?pagina=162',
#  '?pagina=163',
#  '?pagina=164',
#  '?pagina=165',
#  '?pagina=166',
#  '?pagina=167',
#  '?pagina=168',
#  '?pagina=169',
#  '?pagina=170',
#  '?pagina=171',
#  '?pagina=172',
#  '?pagina=173',
#  '?pagina=174',
#  '?pagina=175',
#  '?pagina=176',
#  '?pagina=177',
#  '?pagina=178',
#  '?pagina=179',
#  '?pagina=180',
#  '?pagina=181',
#  '?pagina=182',
#  '?pagina=183',
#  '?pagina=184',
#  '?pagina=185',
#  '?pagina=186',
#  '?pagina=187',
#  '?pagina=188',
#  '?pagina=189',
#  '?pagina=190',
#  '?pagina=191',
#  '?pagina=192',
#  '?pagina=193',
#  '?pagina=194',
#  '?pagina=195',
#  '?pagina=196',
#  '?pagina=197',
#  '?pagina=198',
#  '?pagina=199']

# %%
URL = 'https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/{}'

# %%
df_lista = []
for pg in paginas:
    url = URL.format(pg)
    print('Coletando URL:', url)
    try:
        df = scrap(url)
    except Exception as e:
        print('Erro ao coletar dados na url:', url)
        print(e)
    df_lista.append(df)

df_final = pd.concat(df_lista)
# Out:
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=2
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=3
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=4
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=5
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=6
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=8
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=9
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=10
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=11
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=12
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=13
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=14
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=15
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=16
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=17
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=18
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=19
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=20
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=21
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=22
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=23
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=24
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=25
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=26
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=27
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=28
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=29
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=30
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=31
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=32
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=33
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=34
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=35
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=36
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=37
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=38
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=39
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=40
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=41
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=42
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=43
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=44
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=45
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=46
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=47
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=48
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=49
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=50
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=51
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=52
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=53
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=54
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=55
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=56
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=57
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=58
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=59
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=60
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=61
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=62
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=63
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=64
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=65
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=66
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=67
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=68
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=69
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=70
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=71
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=72
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=73
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=74
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=75
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=76
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=77
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=78
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=79
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=80
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=81
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=82
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=83
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=84
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=85
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=86
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=87
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=88
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=89
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=90
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=91
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=92
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=93
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=94
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=95
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=96
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=97
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=98
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=99
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=100
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=101
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=102
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=103
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=104
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=105
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=106
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=107
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=108
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=109
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=110
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=111
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=112
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=113
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=114
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=115
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=116
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=117
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=118
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=119
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=120
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=121
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=122
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=123
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=124
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=125
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=126
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=127
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=128
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=129
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=130
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=131
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=132
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=133
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=134
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=135
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=136
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=137
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=138
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=139
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=140
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=141
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=142
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=143
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=144
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=145
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=146
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=147
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=148
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=149
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=150
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=151
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=152
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=153
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=154
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=155
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=156
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=157
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=158
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=159
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=160
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=161
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=162
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=163
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=164
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=165
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=166
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=167
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=168
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=169
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=170
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=171
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=172
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=173
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=174
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=175
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=176
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=177
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=178
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=179
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=180
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=181
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=182
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=183
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=184
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=185
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=186
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=187
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=188
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=189
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=190
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=191
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=192
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=193
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=194
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=195
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=196
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=197
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=198
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/apartamento_residencial/?pagina=199

# %%
df_final.head()
# Out:
#                                aluguel          quartos  \
# 0                      R$ 2.000 /Mês      2   Quartos
# 1                      R$ 7.000 /Mês      2   Quartos
# 2                      R$ 1.100 /Mês      2   Quartos
# 3                        R$ 800 /Mês       1   Quarto
# 4     R$ 5.200 /Mês    R$ 1.249.000       2   Quartos
#
#                                             endereco           banheiro  \
# 0  Rua Comendador Miguel Calfat, 62 - Vila Nova C...    2   Banheiros
# 1  Rua Volta Redonda, 757 - Campo Belo, São Paulo...    5   Banheiros
# 2  Avenida do Oratório, 5923 - Jardim Ângela (Zon...    2   Banheiros
# 3  Rua Gomes de Carvalho, 1005 - Vila Olímpia, Sã...     1   Banheiro
# 4  Rua Nova York - Brooklin Paulista, São Paulo - SP    2   Banheiros
#
#             vaga          area
# 0     1   Vaga       56   m²
# 1    3   Vagas      276   m²
# 2     1   Vaga      122   m²
# 3     1   Vaga       30   m²
# 4     1   Vaga       71   m²

# %%
df_final['bairro'] = df_final.endereco.str.split('\s-').str[1]
df_final['rua'] = df_final.endereco.str.split('\s-').str[0]
df_final['bairro'] = df_final.bairro.str.split(',').str[0]

df_final.head()
# Out:
#                                aluguel          quartos  \
# 0                      R$ 2.000 /Mês      2   Quartos
# 1                      R$ 7.000 /Mês      2   Quartos
# 2                      R$ 1.100 /Mês      2   Quartos
# 3                        R$ 800 /Mês       1   Quarto
# 4     R$ 5.200 /Mês    R$ 1.249.000       2   Quartos
#
#                                             endereco           banheiro  \
# 0  Rua Comendador Miguel Calfat, 62 - Vila Nova C...    2   Banheiros
# 1  Rua Volta Redonda, 757 - Campo Belo, São Paulo...    5   Banheiros
# 2  Avenida do Oratório, 5923 - Jardim Ângela (Zon...    2   Banheiros
# 3  Rua Gomes de Carvalho, 1005 - Vila Olímpia, Sã...     1   Banheiro
# 4  Rua Nova York - Brooklin Paulista, São Paulo - SP    2   Banheiros
#
#             vaga          area                       bairro  \
# 0     1   Vaga       56   m²            Vila Nova Conceição
# 1    3   Vagas      276   m²                     Campo Belo
# 2     1   Vaga      122   m²     Jardim Ângela (Zona Leste)
# 3     1   Vaga       30   m²                   Vila Olímpia
# 4     1   Vaga       71   m²              Brooklin Paulista
#
#                                 rua
# 0  Rua Comendador Miguel Calfat, 62
# 1            Rua Volta Redonda, 757
# 2         Avenida do Oratório, 5923
# 3       Rua Gomes de Carvalho, 1005
# 4                     Rua Nova York

# %%
df_final.shape
# Out:
# (7164, 8)

# %%
df_final.to_csv('banco_alu')
