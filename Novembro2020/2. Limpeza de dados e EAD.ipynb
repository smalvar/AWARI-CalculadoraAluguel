# %% [markdown]
# <a href="https://colab.research.google.com/github/smalvar/CalculadoraAluguel-Novembro/blob/main/2.%20Limpeza%20de%20dados%20e%20EAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('banco_imoveis.csv',dtype = str)
df = df.drop(['Unnamed: 0'],axis=1)

# %%
df.head(10)
# Out:
#               aluguel          quartos  \
# 0     R$ 7.000 /Mês      2   Quartos
# 1     R$ 1.650 /Mês      2   Quartos
# 2     R$ 2.400 /Mês       1   Quarto
# 3     R$ 1.900 /Mês      2   Quartos
# 4     R$ 1.900 /Mês      2   Quartos
# 5     R$ 1.900 /Mês       1   Quarto
# 6     R$ 3.400 /Mês      2   Quartos
# 7     R$ 3.400 /Mês      2   Quartos
# 8     R$ 4.200 /Mês      2   Quartos
# 9     R$ 2.500 /Mês       1   Quarto
#
#                                             endereco           banheiro  \
# 0  Rua Volta Redonda, 757 - Campo Belo, São Paulo...    5   Banheiros
# 1  Rua Professor Demóstenes Batista Figueira Marq...     1   Banheiro
# 2  Rua Cristiano Viana, 463 - Cerqueira César, Sã...     1   Banheiro
# 3  Rua Afonso Pena, 560 - Bom Retiro, São Paulo - SP     1   Banheiro
# 4     Rua Araquém, 19 - Vila Mascote, São Paulo - SP    3   Banheiros
# 5  Rua Adolfo Gordo, 52 - Campos Elíseos, São Pau...     1   Banheiro
# 6  Rua Caconde, 310 - Jardim Paulista, São Paulo ...    2   Banheiros
# 7  Rua Oscar Caravelas, 280 - Sumarezinho, São Pa...    2   Banheiros
# 8      Rua Helena, 52 - Vila Olímpia, São Paulo - SP    2   Banheiros
# 9  Avenida Vereador José Diniz, 3100 - Santo Amar...     1   Banheiro
#
#             vaga          area bairro  rua
# 0    3   Vagas      276   m²      NaN  NaN
# 1     1   Vaga       60   m²      NaN  NaN
# 2     1   Vaga       45   m²      NaN  NaN
# 3     1   Vaga       42   m²      NaN  NaN
# 4     1   Vaga       84   m²      NaN  NaN
# 5     1   Vaga       37   m²      NaN  NaN
# 6     1   Vaga      130   m²      NaN  NaN
# 7    2   Vagas       88   m²      NaN  NaN
# 8     1   Vaga       60   m²      NaN  NaN
# 9     1   Vaga       35   m²      NaN  NaN

# %%
df['bairro'] = df.endereco.str.split('\s-').str[1]
df['rua'] = df.endereco.str.split('\s-').str[0]
df['bairro'] = df.bairro.str.split(',').str[0]

df.head()
# Out:
#               aluguel          quartos  \
# 0     R$ 7.000 /Mês      2   Quartos
# 1     R$ 1.650 /Mês      2   Quartos
# 2     R$ 2.400 /Mês       1   Quarto
# 3     R$ 1.900 /Mês      2   Quartos
# 4     R$ 1.900 /Mês      2   Quartos
#
#                                             endereco           banheiro  \
# 0  Rua Volta Redonda, 757 - Campo Belo, São Paulo...    5   Banheiros
# 1  Rua Professor Demóstenes Batista Figueira Marq...     1   Banheiro
# 2  Rua Cristiano Viana, 463 - Cerqueira César, Sã...     1   Banheiro
# 3  Rua Afonso Pena, 560 - Bom Retiro, São Paulo - SP     1   Banheiro
# 4     Rua Araquém, 19 - Vila Mascote, São Paulo - SP    3   Banheiros
#
#             vaga          area            bairro  \
# 0    3   Vagas      276   m²          Campo Belo
# 1     1   Vaga       60   m²             Cambuci
# 2     1   Vaga       45   m²     Cerqueira César
# 3     1   Vaga       42   m²          Bom Retiro
# 4     1   Vaga       84   m²        Vila Mascote
#
#                                                  rua
# 0                             Rua Volta Redonda, 757
# 1  Rua Professor Demóstenes Batista Figueira Marq...
# 2                           Rua Cristiano Viana, 463
# 3                               Rua Afonso Pena, 560
# 4                                    Rua Araquém, 19

# %%
df.columns
# Out:
# Index(['aluguel', 'quartos', 'endereco', 'banheiro', 'vaga', 'area', 'bairro',
#        'rua'],
#       dtype='object')

# %%
all_columns = list(df)
df[all_columns] = df[all_columns].astype(str)

# %%
df.dtypes
# Out:
# aluguel     object
# quartos     object
# endereco    object
# banheiro    object
# vaga        object
# area        object
# bairro      object
# rua         object
# dtype: object

# %%
df['area'] = df['area'].str.extract('(.*) m²')

# %%
df.head()
# Out:
#               aluguel          quartos  \
# 0     R$ 7.000 /Mês      2   Quartos
# 1     R$ 1.650 /Mês      2   Quartos
# 2     R$ 2.400 /Mês       1   Quarto
# 3     R$ 1.900 /Mês      2   Quartos
# 4     R$ 1.900 /Mês      2   Quartos
#
#                                             endereco           banheiro  \
# 0  Rua Volta Redonda, 757 - Campo Belo, São Paulo...    5   Banheiros
# 1  Rua Professor Demóstenes Batista Figueira Marq...     1   Banheiro
# 2  Rua Cristiano Viana, 463 - Cerqueira César, Sã...     1   Banheiro
# 3  Rua Afonso Pena, 560 - Bom Retiro, São Paulo - SP     1   Banheiro
# 4     Rua Araquém, 19 - Vila Mascote, São Paulo - SP    3   Banheiros
#
#             vaga     area            bairro  \
# 0    3   Vagas      276          Campo Belo
# 1     1   Vaga       60             Cambuci
# 2     1   Vaga       45     Cerqueira César
# 3     1   Vaga       42          Bom Retiro
# 4     1   Vaga       84        Vila Mascote
#
#                                                  rua
# 0                             Rua Volta Redonda, 757
# 1  Rua Professor Demóstenes Batista Figueira Marq...
# 2                           Rua Cristiano Viana, 463
# 3                               Rua Afonso Pena, 560
# 4                                    Rua Araquém, 19

# %%
df['vaga'] = df['vaga'].str.extract('(.*) Vaga')

# %%
df.head()
# Out:
#               aluguel          quartos  \
# 0     R$ 7.000 /Mês      2   Quartos
# 1     R$ 1.650 /Mês      2   Quartos
# 2     R$ 2.400 /Mês       1   Quarto
# 3     R$ 1.900 /Mês      2   Quartos
# 4     R$ 1.900 /Mês      2   Quartos
#
#                                             endereco           banheiro  \
# 0  Rua Volta Redonda, 757 - Campo Belo, São Paulo...    5   Banheiros
# 1  Rua Professor Demóstenes Batista Figueira Marq...     1   Banheiro
# 2  Rua Cristiano Viana, 463 - Cerqueira César, Sã...     1   Banheiro
# 3  Rua Afonso Pena, 560 - Bom Retiro, São Paulo - SP     1   Banheiro
# 4     Rua Araquém, 19 - Vila Mascote, São Paulo - SP    3   Banheiros
#
#     vaga     area            bairro  \
# 0    3      276          Campo Belo
# 1    1       60             Cambuci
# 2    1       45     Cerqueira César
# 3    1       42          Bom Retiro
# 4    1       84        Vila Mascote
#
#                                                  rua
# 0                             Rua Volta Redonda, 757
# 1  Rua Professor Demóstenes Batista Figueira Marq...
# 2                           Rua Cristiano Viana, 463
# 3                               Rua Afonso Pena, 560
# 4                                    Rua Araquém, 19

# %%
df['banheiro'] = df['banheiro'].str.extract('(.*) Banheiro')
df['quartos'] = df['quartos'].str.extract('(.*) Quarto')
df.head()
# Out:
#               aluguel quartos  \
# 0     R$ 7.000 /Mês       2
# 1     R$ 1.650 /Mês       2
# 2     R$ 2.400 /Mês       1
# 3     R$ 1.900 /Mês       2
# 4     R$ 1.900 /Mês       2
#
#                                             endereco banheiro   vaga     area  \
# 0  Rua Volta Redonda, 757 - Campo Belo, São Paulo...      5      3      276
# 1  Rua Professor Demóstenes Batista Figueira Marq...      1      1       60
# 2  Rua Cristiano Viana, 463 - Cerqueira César, Sã...      1      1       45
# 3  Rua Afonso Pena, 560 - Bom Retiro, São Paulo - SP      1      1       42
# 4     Rua Araquém, 19 - Vila Mascote, São Paulo - SP      3      1       84
#
#              bairro                                                rua
# 0        Campo Belo                             Rua Volta Redonda, 757
# 1           Cambuci  Rua Professor Demóstenes Batista Figueira Marq...
# 2   Cerqueira César                           Rua Cristiano Viana, 463
# 3        Bom Retiro                               Rua Afonso Pena, 560
# 4      Vila Mascote                                    Rua Araquém, 19

# %%
df.shape
# Out:
# (1102, 8)

# %%
df['aluguel'] = df['aluguel'].str.extract('R\$ (.*) /Mês')
df['aluguel'] = df['aluguel'].replace('\.', '', regex=True)
df.head()
# Out:
#   aluguel quartos                                           endereco banheiro  \
# 0    7000     2    Rua Volta Redonda, 757 - Campo Belo, São Paulo...      5
# 1    1650     2    Rua Professor Demóstenes Batista Figueira Marq...      1
# 2    2400     1    Rua Cristiano Viana, 463 - Cerqueira César, Sã...      1
# 3    1900     2    Rua Afonso Pena, 560 - Bom Retiro, São Paulo - SP      1
# 4    1900     2       Rua Araquém, 19 - Vila Mascote, São Paulo - SP      3
#
#     vaga     area            bairro  \
# 0    3      276          Campo Belo
# 1    1       60             Cambuci
# 2    1       45     Cerqueira César
# 3    1       42          Bom Retiro
# 4    1       84        Vila Mascote
#
#                                                  rua
# 0                             Rua Volta Redonda, 757
# 1  Rua Professor Demóstenes Batista Figueira Marq...
# 2                           Rua Cristiano Viana, 463
# 3                               Rua Afonso Pena, 560
# 4                                    Rua Araquém, 19

# %%
df['endereco'].nunique()
# Out:
# 974

# %%
df = df.drop_duplicates(subset=['endereco','aluguel'], keep='first', inplace=False)

# %%
df.shape
# Out:
# (1098, 8)

# %%
df.to_csv('limpo.csv')

# %%
df.describe()
# Out:
#        aluguel quartos                                    endereco banheiro  \
# count     1098    1098                                        1098     1098
# unique     242      11                                         974       12
# top       3000     1    Avenida Moema, 177 - Moema, São Paulo - SP      1
# freq        38     333                                           8      448
#
#          vaga    area bairro                 rua
# count    1098    1098   1098                1098
# unique     20     311    262                 922
# top       1      30       SP  Avenida Moema, 177
# freq      389      34    149                   8

# %%
cols = df.columns.drop(['endereco','bairro','rua'])

# %%
cols
# Out:
# Index(['aluguel', 'quartos', 'banheiro', 'vaga', 'area'], dtype='object')

# %%
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1098 entries, 0 to 1101
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aluguel   1098 non-null   int64
#  1   quartos   1068 non-null   float64
#  2   endereco  1098 non-null   object
#  3   banheiro  1091 non-null   float64
#  4   vaga      891 non-null    float64
#  5   area      1098 non-null   int64
#  6   bairro    1098 non-null   object
#  7   rua       1098 non-null   object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 77.2+ KB

# %%
df.describe()
# Out:
#              aluguel      quartos     banheiro        vaga         area
# count    1098.000000  1068.000000  1091.000000  891.000000  1098.000000
# mean     7412.638434     2.441011     2.597617    2.815937   191.764117
# std     11628.341855     1.336280     1.858369    3.373694   243.575785
# min       500.000000     1.000000     1.000000    1.000000     0.000000
# 25%      1864.000000     1.000000     1.000000    1.000000    45.000000
# 50%      3275.000000     2.000000     2.000000    2.000000    94.500000
# 75%      8000.000000     3.000000     4.000000    4.000000   250.000000
# max    110000.000000    11.000000    11.000000   40.000000  2000.000000

# %%
min(df.aluguel)
# Out:
# 500

# %%
df.head(20)
# Out:
#     aluguel  quartos                                           endereco  \
# 0      7000      2.0  Rua Volta Redonda, 757 - Campo Belo, São Paulo...
# 1      1650      2.0  Rua Professor Demóstenes Batista Figueira Marq...
# 2      2400      1.0  Rua Cristiano Viana, 463 - Cerqueira César, Sã...
# 3      1900      2.0  Rua Afonso Pena, 560 - Bom Retiro, São Paulo - SP
# 4      1900      2.0     Rua Araquém, 19 - Vila Mascote, São Paulo - SP
# 5      1900      1.0  Rua Adolfo Gordo, 52 - Campos Elíseos, São Pau...
# 6      3400      2.0  Rua Caconde, 310 - Jardim Paulista, São Paulo ...
# 7      3400      2.0  Rua Oscar Caravelas, 280 - Sumarezinho, São Pa...
# 8      4200      2.0      Rua Helena, 52 - Vila Olímpia, São Paulo - SP
# 9      2500      1.0  Avenida Vereador José Diniz, 3100 - Santo Amar...
# 10     1800      2.0  Avenida Itaboraí - Bosque da Saúde, São Paulo ...
# 11     4574      3.0     Rua Viradouro, 96 - Itaim Bibi, São Paulo - SP
# 12     2000      3.0         Rua Eli - Vila Maria Baixa, São Paulo - SP
# 13     4800      3.0  Rua Barão de Jaceguai, 1305 - Campo Belo, São ...
# 14     2700      1.0  Rua da Consolação, 1515 - Consolação, São Paul...
# 15     5400      2.0  Rua Peixoto Gomide, 596 - Jardim Paulista, São...
# 16     2900      3.0  Avenida Moaci, 780 - Planalto Paulista, São Pa...
# 17     1800      2.0  Rua Dom Constantino Barradas, 120 - Vila Gumer...
# 18     4985      2.0  Rua Silva Correia, 125 - Vila Nova Conceição, ...
# 19     2600      2.0     Rua Pamplona - Jardim Paulista, São Paulo - SP
#
#     banheiro  vaga  area                bairro  \
# 0        5.0   3.0   276            Campo Belo
# 1        1.0   1.0    60               Cambuci
# 2        1.0   1.0    45       Cerqueira César
# 3        1.0   1.0    42            Bom Retiro
# 4        3.0   1.0    84          Vila Mascote
# 5        1.0   1.0    37        Campos Elíseos
# 6        2.0   1.0   130       Jardim Paulista
# 7        2.0   2.0    88           Sumarezinho
# 8        2.0   1.0    60          Vila Olímpia
# 9        1.0   1.0    35           Santo Amaro
# 10       1.0   1.0    62       Bosque da Saúde
# 11       2.0   1.0   100            Itaim Bibi
# 12       2.0   1.0    73      Vila Maria Baixa
# 13       3.0   2.0   130            Campo Belo
# 14       1.0   1.0    33            Consolação
# 15       2.0   1.0    72       Jardim Paulista
# 16       3.0   1.0    99     Planalto Paulista
# 17       2.0   2.0    80       Vila Gumercindo
# 18       3.0   2.0    86   Vila Nova Conceição
# 19       2.0   1.0    91       Jardim Paulista
#
#                                                   rua
# 0                              Rua Volta Redonda, 757
# 1   Rua Professor Demóstenes Batista Figueira Marq...
# 2                            Rua Cristiano Viana, 463
# 3                                Rua Afonso Pena, 560
# 4                                     Rua Araquém, 19
# 5                                Rua Adolfo Gordo, 52
# 6                                    Rua Caconde, 310
# 7                            Rua Oscar Caravelas, 280
# 8                                      Rua Helena, 52
# 9                   Avenida Vereador José Diniz, 3100
# 10                                   Avenida Itaboraí
# 11                                  Rua Viradouro, 96
# 12                                            Rua Eli
# 13                        Rua Barão de Jaceguai, 1305
# 14                            Rua da Consolação, 1515
# 15                            Rua Peixoto Gomide, 596
# 16                                 Avenida Moaci, 780
# 17                  Rua Dom Constantino Barradas, 120
# 18                             Rua Silva Correia, 125
# 19                                       Rua Pamplona

# %%
df.isnull().sum()
# Out:
# aluguel       0
# quartos      30
# endereco      0
# banheiro      7
# vaga        207
# area          0
# bairro        0
# rua           0
# dtype: int64

# %%
df = df.fillna(0)
df.isnull().sum()
# Out:
# aluguel     0
# quartos     0
# endereco    0
# banheiro    0
# vaga        0
# area        0
# bairro      0
# rua         0
# dtype: int64

# %%
df.aluguel.hist()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.distplot(df['aluguel']);

# %%
sns.boxplot(data = df['aluguel'], orient='horizontal')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(df['area'], df['aluguel'], alpha=0.2)
#x = [0, 400, 1000]
#y = [0, 10000, 20000]
#plt.plot(x, y, c='r')
plt.xlabel('Área')
plt.ylabel('Aluguel')
# Out:
# Text(0, 0.5, 'Aluguel')

# %%
sns.pairplot(df, kind='reg')

# %%
sns.pairplot(df)

# %%
g = sns.pairplot(df, plot_kws={'alpha':0.1})

# %%
df.corr()
# Out:
#            aluguel   quartos  banheiro      vaga      area
# aluguel   1.000000  0.489941  0.613367  0.495619  0.724069
# quartos   0.489941  1.000000  0.732924  0.455138  0.595079
# banheiro  0.613367  0.732924  1.000000  0.529569  0.686052
# vaga      0.495619  0.455138  0.529569  1.000000  0.564135
# area      0.724069  0.595079  0.686052  0.564135  1.000000

# %%
sns.heatmap(df.corr(), annot=True, center=0)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(), annot=True, center=0, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
df.boxplot('aluguel')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='bairro', y='aluguel', data=df)
# Out:
# <AxesSubplot:xlabel='bairro', ylabel='aluguel'>

# %%
centro = ['Centro','Bela Vista','Bom Retiro','Cambuci','Consolação','Vila Monumento','Luz',
          'Higienópolis','Liberdade','República','Santa Cecília','Sé','Paraíso','Santa Efigênia',
         'Aclimação','Campos Eliseos','Campos Elíseos','Cerqueira César','Planalto Paulista',
         'Vila Monte Alegre','Vila Buarque','Jardim da Glória','Vila Moinho Velho']

norte = ['Norte','Anhanguera','Brasilândia','Casa Verde','Cachoeirinha','Freguesia do Ó','Jaçanã','Jaraguá',
    'Limão','Mandaqui','Perus','Pirituba','Santana','São Domingos','Tremembé','Tucuruvi','Vila Maria','Vila Iório',
    'Vila Medeiros','Vila Guilherme','Jardim Peri Peri','Vila Constança','City América','Jardim Yara',
        'Vila Paulistana','Sitio Botuquara','Jardim Shangrila','Jardim Franca','Vila Isolina Mazzei','Chora Menino',
        'Vila Zat','Água Fria','Jardim Japão','Vila Mangalot','Vila Carbone','Sítio Botuquara','Horto Florestal',
        'Vila Nova Mazzei','Imirim','Jardim São Paulo','Vila Libanesa','Vila Americana','Parque São Luís',
        'Lauzane Paulista','Vila Palmeiras','Vila Ede','Vila Prado']

sul = ['Sul','Campo Belo','Campo Limpo','Capão Redondo','Cidade Ademar','Cidade Dutra','Cursino','Grajaú',
    'Itaim Bibi','Ipiranga','Jabaquara' ,'Jardim Ângela' ,'Jardim São Luís','Marsilac', 'Moema',
    'Moema Pássaros','Moema Índios','Morumbi','Parelheiros','Pedreira','Sacomã','Jardim Avenida',
    'Santo Amaro','Socorro','Saúde','Vila Andrade','Vila Mariana','Vila Olímpia','Vila Mascote','Brooklin',
       'Vila Gumercindo','Vila Cruzeiro','Vila Gertrudes','Vila Arriete','Parque Colonial','Vila Clementino',
       'Vila Sofia','Vila Uberabinha','Jardim Dom Bosco','Jardim Aeroporto','Vila Congonhas','Indianópolis',
       'Brooklin Novo','Brooklin Paulista','Cidade das Monções','Cidade Monções','Jardins','Vila Nova Conceição',
      'Chácara Inglesa','Vila Santa Maria','Balneário Mar Paulista','Ferreira','Jardim Prudência','Chácara Flora',
      'Vila Tramontano','Jardim Hípico','Chácara Nossa Senhora do Bom Conselho','Cidade Domitila','Vila Castelo',
       'Chácara Santo Antônio','Jardim das Acacias','Vila Santo Estéfano','Alto Da Boa Vista','Parque Lagoa Rica',
      'Jardim Petrópolis','Guarapiranga','Jardim Cordeiro','Jardim dos Estados','Chácara Santa Maria',
      'Jardim das Acácias','Jardim Aurélia','Jardim Ampliação','Jardim Satélite','Interlagos','Jardim da Saude',
      'Jardim Represa','Jardim Vitória Régia','Jardim Sandra','Real Parque','Vila Dom Pedro I','Vila Guarani',
       'Chácara Vista Alegre','Vila Cordeiro','Jardim Santo Antoninho','Vila Santa Catarina','Nova Piraju',
      'Jordanópolis','Jardim Iracema','Vila Anhangüera','Vila Nair','Jardim Leonor','Chácara Bosque do Sol',
      'Vila Império','Vila Imperio','Jardim dos Lagos','Jardim Vilas Boas','Jardim Panorama','Chácara Monte Alegre',
       'Jardim Caboré','Jardim Taquaral','Praia da Lagoa','Jardim Marajoara','Paulicéia','Varginha',
       'Cidade Jardim','Jardim Francisco Mendes','Jardim Santa Tereza','Alto da Boa Vista','Parque Maria Fernandes']

leste = ['Leste','Água Rasa','Aricanduva','Artur Alvim','Belém','Brás','Cangaíba','Carrão','Cidade Líder',
    'Cidade Tiradentes','Ermelino Matarazzo','Guaianases','Itaim Paulista','Itaquera','Vila Invernada',
    'Jardim Helena','José Bonifácio','Lajeado','Mooca','Pari','Parque do Carmo','Penha','Vila Primavera',
    'Ponte Rasa','São Lucas','São Mateus','São Miguel','São Rafael','Sapopemba','Tatuapé','São João Clímaco',
         'Quarta Parada','Jardim Tietê','Vila Antonieta','Cidade Mãe do Céu','Vila Regente Feijó','Vila Antonina',
         'Chácara Belenzinho','Belenzinho','Jardim Egle','Cidade Vargas','Cidade Satélite Santa Bárbara',
    'Vila Curuçá','Vila Formosa','Vila Jacuí','Vila Matilde','Vila Prudente','Mooca','Tatuapé','Carandiru',
         'Mirandópolis','Vila Brasilina','Móoca','Jardim Anália Franco','Parque São Jorge','Sítio Pinheirinho',
        'Vila Pierina','Vila São Silvestre','Vila Ema','Parque Novo Mundo','Jardim Paraguaçu','Vila Santo Estevão',
        'Conjunto Habitacional Barreira Grande','Vila Santa Clara','Parque Savoy City','Jardim Avelino',
        'Vila Azevedo','Vila Dalila','Vila Bertioga','Jardim Popular']


oeste = ['Oeste','Alto de Pinheiros','Barra Funda','Butantã','Jaguará','Jardim Paulista','Jardim Paulistano',
    'Jardim Europa','Jardim América','Lapa','Morumbi','Perdizes','Pinheiros','Raposo Tavares','Rio Pequeno'
    'Vila Leopoldina','Vila Madalena','Vila Sônia','Sumarezinho','Sumaré','Boaçava','Jardim das Vertentes',
        'Rio Pequeno','Vila Leopoldina','Panamby','Jardim Monte Kemel','Pompeia','Vila Pompéia',
         'Vila Anglo Brasileira','Vila Romana','Pacaembu','Água Branca','Jardim Guedala','Jardim Everest',
        'Vila Gomes','Jardim das Bandeiras','Jardim Umuarama','Jardim Esmeralda','Jaguaré','Jardim Bonfiglioli',
        'Vila Inah','Jardim Rizzo','Vila Suzana','Parque Ipê','Vila Indiana','Cidade São Francisco',
         'Granja Julieta','Bela Aliança','Caxingui','Vila Tiradentes','Lar São Paulo',
        'Vila Progredior','Vila São Francisco','Vila Prel','Jardim Celeste']

nenhuma = ['nenhuma']

# %%
bairros = nenhuma + sul + oeste + norte + sul + centro + leste

# %%
def checarN_zona(df,lista):
    df = df[~df.endereco.str.contains('|'.join(bairros))]
    df['zona'] = str(lista[0])
    return df

# %%
df7 = checarN_zona(df,bairros)

# %%
df7.shape
# Out:
# (0, 9)

# %%
def checar_zona(df,lista):
    df = df[df.endereco.str.contains('|'.join(lista))]
    df['zona'] = str(lista[0])
    return df

# %%
df1 = checar_zona(df,oeste)
df1.shape
# Out:
# /home/sara/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# (281, 9)

# %%
df2 = checar_zona(df,sul)
df3 = checar_zona(df,leste)
df4 = checar_zona(df,centro)
df5 = checar_zona(df,norte)
# Out:
# /home/sara/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_concat = pd.concat([df1,df2,df3,df4,df5,df7])

# %%
df_concat.shape
# Out:
# (1186, 9)

# %%
df_final = df_concat.drop_duplicates(subset=['endereco','aluguel'], keep='last', inplace=False)

# %%
df_final.shape
# Out:
# (1098, 9)

# %%
sns.pairplot(df_final,hue='zona')

# %%
sns.boxplot(x='zona', y='aluguel', data=df_final)
# Out:
# <AxesSubplot:xlabel='zona', ylabel='aluguel'>

# %%
df_final.describe()
# Out:
#              aluguel      quartos     banheiro         vaga         area
# count    1098.000000  1098.000000  1098.000000  1098.000000  1098.000000
# mean     7412.638434     2.374317     2.581056     2.285064   191.764117
# std     11628.341855     1.376703     1.863942     3.232382   243.575785
# min       500.000000     0.000000     0.000000     0.000000     0.000000
# 25%      1864.000000     1.000000     1.000000     1.000000    45.000000
# 50%      3275.000000     2.000000     2.000000     1.000000    94.500000
# 75%      8000.000000     3.000000     4.000000     3.000000   250.000000
# max    110000.000000    11.000000    11.000000    40.000000  2000.000000
