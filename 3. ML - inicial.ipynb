# %% [markdown]
# <a href="https://colab.research.google.com/github/smalvar/CalculadoraAluguel-Novembro/blob/main/2.%20Limpeza%20de%20dados%20e%20EAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/smalvar/CalculadoraAluguel-Novembro/main/banco_final.csv')

# %%
dados = dados.drop(['Unnamed: 0'],axis=1)
dados.head()
# Out:
#    aluguel  quartos                                           endereco  \
# 0     3400      2.0  Rua Caconde, 310 - Jardim Paulista, São Paulo ...
# 1     3400      2.0  Rua Oscar Caravelas, 280 - Sumarezinho, São Pa...
# 2     5400      2.0  Rua Peixoto Gomide, 596 - Jardim Paulista, São...
# 3     2600      2.0     Rua Pamplona - Jardim Paulista, São Paulo - SP
# 4     3800      1.0                          Pinheiros, São Paulo - SP
#
#    banheiro  vaga  area            bairro                       rua   zona
# 0       2.0   1.0   130   Jardim Paulista          Rua Caconde, 310  Oeste
# 1       2.0   2.0    88       Sumarezinho  Rua Oscar Caravelas, 280  Oeste
# 2       2.0   1.0    72   Jardim Paulista   Rua Peixoto Gomide, 596  Oeste
# 3       2.0   1.0    91   Jardim Paulista              Rua Pamplona  Oeste
# 4       1.0   1.0    44                SP      Pinheiros, São Paulo  Oeste

# %%
dados[(dados.zona=='Oeste')&(dados.quartos<=2.0)&(dados.area==72)]
# Out:
#     aluguel  quartos                                           endereco  \
# 2      5400      2.0  Rua Peixoto Gomide, 596 - Jardim Paulista, São...
# 27     4990      2.0  Rua Capote Valente, 467 - Pinheiros, São Paulo...
# 70     1500      2.0  Rua Coronel Camisão, 409 - Vila Gomes, São Pau...
#
#     banheiro  vaga  area            bairro                       rua   zona
# 2        2.0   1.0    72   Jardim Paulista   Rua Peixoto Gomide, 596  Oeste
# 27       2.0   1.0    72         Pinheiros   Rua Capote Valente, 467  Oeste
# 70       2.0   1.0    72        Vila Gomes  Rua Coronel Camisão, 409  Oeste

# %%
dados[(dados.zona=='Oeste')&(dados.quartos<=3.0)&(dados.area==72)]['aluguel'].mean()
# Out:
# 3322.5

# %% [markdown]
# > Esse é um estimador! O KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=3)
neigh.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-70cf6a7e0074> in <module>
#       1 from sklearn.neighbors import KNeighborsRegressor
#       2 neigh = KNeighborsRegressor(n_neighbors=3)
# ----> 3 neigh.fit(X, y)
#
# NameError: name 'X' is not defined

# %%
X = dados[['zona', 'area', 'quartos','banheiro','vaga']]
y = dados['aluguel']

# %%
neigh = KNeighborsRegressor(n_neighbors=3)
neigh.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-1aff0869c8a5> in <module>
#       1 neigh = KNeighborsRegressor(n_neighbors=3)
# ----> 2 neigh.fit(X, y)
#
# ~/.local/lib/python3.6/site-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1108         """
#    1109         if not isinstance(X, (KDTree, BallTree)):
# -> 1110             X, y = check_X_y(X, y, "csr", multi_output=True)
#    1111         self._y = y
#    1112         return self._fit(X)
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Oeste'

# %%
X = pd.get_dummies(X)

# %%
X.head()
# Out:
#    area  quartos  banheiro  vaga  zona_Centro  zona_Leste  zona_Norte  \
# 0   130      2.0       2.0   1.0            0           0           0
# 1    88      2.0       2.0   2.0            0           0           0
# 2    72      2.0       2.0   1.0            0           0           0
# 3    91      2.0       2.0   1.0            0           0           0
# 4    44      1.0       1.0   1.0            0           0           0
#
#    zona_Oeste  zona_Sul
# 0           1         0
# 1           1         0
# 2           1         0
# 3           1         0
# 4           1         0

# %%
neigh = KNeighborsRegressor(n_neighbors=3)
neigh.fit(X, y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform')

# %%
neigh.predict([[72, 2, 2, 1, 0, 0, 0, 1, 0]]) #dados[['zona', 'area', 'quartos','banheiro','vaga']]
# Out:
# array([3963.33333333])

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(dados['area'],dados['aluguel'])

# %%
plt.scatter(np.log(dados['area']),np.log(dados['aluguel']))

# %%
dados_reduzidos = dados[['area', 'aluguel']]
dados_reduzidos.head()
# Out:
#    area  aluguel
# 0   130     3400
# 1    88     3400
# 2    72     5400
# 3    91     2600
# 4    44     3800

# %%
X = dados_reduzidos['area']
y = dados_reduzidos['aluguel']

# %%
X.values.shape
# Out:
# (1098,)

# %%
X.values
# Out:
# array([130,  88,  72, ..., 275, 130, 108])

# %%
X.values.reshape(-1, 1)
# Out:
# array([[130],
#        [ 88],
#        [ 72],
#        ...,
#        [275],
#        [130],
#        [108]])

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X.values.reshape(-1, 1), y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([34.56716466])

# %%
reg.intercept_
# Out:
# 783.8966408917568

# %% [markdown]
# $$aluguel = w_1 * area + C$$

# %%
X = dados[['zona', 'area', 'quartos','banheiro','vaga']]
y = dados['aluguel']
X = pd.get_dummies(X)
X = X.dropna()
y=y[X.index]

# %%
X.head()
# Out:
#    area  quartos  banheiro  vaga  zona_Centro  zona_Leste  zona_Norte  \
# 0   130      2.0       2.0   1.0            0           0           0
# 1    88      2.0       2.0   2.0            0           0           0
# 2    72      2.0       2.0   1.0            0           0           0
# 3    91      2.0       2.0   1.0            0           0           0
# 4    44      1.0       1.0   1.0            0           0           0
#
#    zona_Oeste  zona_Sul
# 0           1         0
# 1           1         0
# 2           1         0
# 3           1         0
# 4           1         0

# %%
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([   25.8795294 ,  -243.97330043,  1297.497614  ,   333.59687688,
#          928.93829529, -1539.91785816,  -849.36112437,  1089.13207074,
#          371.2086165 ])

# %% [markdown]
# $$aluguel = w_1 * area + w_2 *	quartos+ w_3 *banheiro + w_4*vaga + w_5*	zonacentro+ w_6 *	zonaleste + w_7 *	zonanorte + w_7 *	zonaoeste + w_8*zonasul +  b$$

# %%
reg.intercept_
# Out:
# -1453.0427412557356

# %%
reg.predict([[72, 2, 2, 1, 0, 0, 0, 1, 0]])
# Out:
# array([3940.06095025])

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(max_depth=3)
dt.fit(X, y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=3,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
from sklearn import tree
plt.figure(figsize=(20,20))
tree.plot_tree(dt, filled=True, feature_names=X.columns);

# %%
area_maximo = 200
area_filtro = dados['area']<=area_maximo

# %%
dt = DecisionTreeRegressor(max_depth=3)
dt.fit(X[area_filtro], y[area_filtro])
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=3,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt, filled=True, feature_names=X.columns);

# %%
plt.scatter(dados[area_filtro]['area'],dados[area_filtro]['aluguel'])

# %%
len(dados[area_filtro]['area'])
# Out:
# 775

# %%
dt.predict([[72, 2, 2, 1, 0, 0, 0, 1, 0]])
# Out:
# array([2897.87234043])
