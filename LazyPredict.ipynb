# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dados = pd.read_csv('df_final.csv')
dados = dados.drop(['url','header','address','crawler','crawled_at'],axis=1)
dados = dados.rename(columns = {'rooms': 'quartos', 'bathrooms': 'banheiros', 'price':'aluguel',
                               'neighborhood':'bairro','garages':'vagas'}, inplace = False)
dados.head()
# Out:
#            id  area  quartos  banheiros vagas  \
# 0  2512663008    30        1          1     1
# 1  2518591697    98        2          2     1
# 2  2518566682   126        3          2     1
# 3  2519041802    78        2          2     1
# 4  2514428582   186        4          4     3
#
#                                            amenities  aluguel   condo  \
# 0  Mobiliado\nPiscina\nAcademia\nAr-condicionado\...  3500.00    2.00
# 1                       Aceita animais\nPortaria 24h  2600.00 1000.00
# 2  Condomínio fechado\nAceita animais\nPortaria 2...  3900.00 1640.00
# 3                             Elevador\nPortaria 24h  2500.00  761.00
# 4  Piscina\nVaranda gourmet\nAcademia\nChurrasque...  7500.00 1730.00
#
#              bairro   zona
# 0     Vila Madalena  Oeste
# 1          Perdizes  Oeste
# 2   Jardim Paulista  Oeste
# 3     Vila Madalena  Oeste
# 4       Vila Suzana  Oeste

# %%
dados = dados[dados['zona'] != 'nenhuma']
dados.vagas = pd.to_numeric(dados.vagas, errors='coerce')
dados.vagas = dados.vagas.fillna(0)
dados = dados[dados['condo'] <= 10000]
dados = dados[dados['vagas'] <= 10]

# %%
dados.head()
# Out:
#            id  area  quartos  banheiros  vagas  \
# 0  2512663008    30        1          1   1.00
# 1  2518591697    98        2          2   1.00
# 2  2518566682   126        3          2   1.00
# 3  2519041802    78        2          2   1.00
# 4  2514428582   186        4          4   3.00
#
#                                            amenities  aluguel   condo  \
# 0  Mobiliado\nPiscina\nAcademia\nAr-condicionado\...  3500.00    2.00
# 1                       Aceita animais\nPortaria 24h  2600.00 1000.00
# 2  Condomínio fechado\nAceita animais\nPortaria 2...  3900.00 1640.00
# 3                             Elevador\nPortaria 24h  2500.00  761.00
# 4  Piscina\nVaranda gourmet\nAcademia\nChurrasque...  7500.00 1730.00
#
#              bairro   zona
# 0     Vila Madalena  Oeste
# 1          Perdizes  Oeste
# 2   Jardim Paulista  Oeste
# 3     Vila Madalena  Oeste
# 4       Vila Suzana  Oeste

# %%
dados = dados.drop(['id','amenities','bairro'],axis=1)

# %%
dados.head()
# Out:
#    area  quartos  banheiros  vagas  aluguel   condo   zona
# 0    30        1          1   1.00  3500.00    2.00  Oeste
# 1    98        2          2   1.00  2600.00 1000.00  Oeste
# 2   126        3          2   1.00  3900.00 1640.00  Oeste
# 3    78        2          2   1.00  2500.00  761.00  Oeste
# 4   186        4          4   3.00  7500.00 1730.00  Oeste

# %%
import lazypredict
import numpy as np
from lazypredict.Supervised import LazyRegressor

# %%
y = dados['aluguel']

# %%
X = dados.drop(['aluguel'],axis=1)
X = pd.get_dummies(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
reg = LazyRegressor(predictions=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 42/42 [00:14<00:00,  2.82it/s]

# %%
models.head(42)
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# HistGradientBoostingRegressor                0.68       0.68   1815.93
# RandomForestRegressor                        0.67       0.67   1834.94
# LGBMRegressor                                0.67       0.67   1842.44
# ExtraTreesRegressor                          0.66       0.67   1855.50
# BaggingRegressor                             0.64       0.65   1908.12
# GradientBoostingRegressor                    0.64       0.64   1918.40
# KNeighborsRegressor                          0.63       0.64   1939.29
# XGBRegressor                                 0.63       0.63   1952.97
# LassoLars                                    0.60       0.60   2033.48
# RidgeCV                                      0.60       0.60   2034.71
# BayesianRidge                                0.60       0.60   2035.16
# LassoCV                                      0.60       0.60   2035.57
# SGDRegressor                                 0.60       0.60   2035.69
# Lasso                                        0.60       0.60   2036.14
# Ridge                                        0.60       0.60   2036.22
# LinearRegression                             0.60       0.60   2036.40
# TransformedTargetRegressor                   0.60       0.60   2036.40
# LassoLarsCV                                  0.60       0.60   2036.40
# Lars                                         0.60       0.60   2036.40
# LarsCV                                       0.60       0.60   2036.40
# LassoLarsIC                                  0.60       0.60   2036.40
# HuberRegressor                               0.59       0.59   2056.69
# PassiveAggressiveRegressor                   0.58       0.59   2063.48
# ElasticNet                                   0.58       0.59   2063.64
# OrthogonalMatchingPursuitCV                  0.58       0.59   2070.35
# RANSACRegressor                              0.56       0.57   2117.09
# AdaBoostRegressor                            0.56       0.56   2123.93
# TweedieRegressor                             0.56       0.56   2130.23
# GeneralizedLinearRegressor                   0.56       0.56   2130.23
# GammaRegressor                               0.53       0.53   2201.14
# OrthogonalMatchingPursuit                    0.49       0.50   2277.36
# ElasticNetCV                                 0.48       0.48   2310.56
# DecisionTreeRegressor                        0.47       0.48   2327.50
# MLPRegressor                                 0.46       0.47   2352.52
# PoissonRegressor                             0.46       0.46   2358.31
# ExtraTreeRegressor                           0.37       0.38   2541.99
# LinearSVR                                    0.17       0.18   2914.33
# NuSVR                                       -0.00       0.01   3207.89
# DummyRegressor                              -0.01      -0.00   3219.02
# SVR                                         -0.04      -0.03   3266.46
# KernelRidge                                 -1.02      -1.00   4554.16
# GaussianProcessRegressor                -33110.33  -32783.79 582663.71
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        0.35
# RandomForestRegressor                0.91
# LGBMRegressor                        0.10
# ExtraTreesRegressor                  0.62
# BaggingRegressor                     0.09
# GradientBoostingRegressor            0.33
# KNeighborsRegressor                  0.13
# XGBRegressor                         0.26
# LassoLars                            0.06
# RidgeCV                              0.08
# BayesianRidge                        0.07
# LassoCV                              0.22
# SGDRegressor                         0.12
# Lasso                                0.08
# Ridge                                0.01
# LinearRegression                     0.02
# TransformedTargetRegressor           0.02
# LassoLarsCV                          0.08
# Lars                                 0.04
# LarsCV                               0.09
# LassoLarsIC                          0.03
# HuberRegressor                       0.35
# PassiveAggressiveRegressor           0.02
# ElasticNet                           0.04
# OrthogonalMatchingPursuitCV          0.03
# RANSACRegressor                      0.13
# AdaBoostRegressor                    0.07
# TweedieRegressor                     0.03
# GeneralizedLinearRegressor           0.02
# GammaRegressor                       0.02
# OrthogonalMatchingPursuit            0.01
# ElasticNetCV                         0.10
# DecisionTreeRegressor                0.10
# MLPRegressor                         4.73
# PoissonRegressor                     0.04
# ExtraTreeRegressor                   0.02
# LinearSVR                            0.02
# NuSVR                                0.94
# DummyRegressor                       0.01
# SVR                                  1.13
# KernelRidge                          1.43
# GaussianProcessRegressor             1.89

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.model_selection import GridSearchCV
parameters=[{'min_samples_leaf':[1,2,4],
             'max_depth':[4,6,8,12,20],
             'n_estimators':[50, 100, 200,400]}]
            
rf = RandomForestRegressor(n_estimators=100, max_depth=1)
gs = GridSearchCV(rf,parameters,scoring='r2',n_jobs=-1,cv=5)
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(max_depth=1), n_jobs=-1,
#              param_grid=[{'max_depth': [4, 6, 8, 12, 20],
#                           'min_samples_leaf': [1, 2, 4],
#                           'n_estimators': [50, 100, 200, 400]}],
#              scoring='r2')

# %%
gs.best_params_
# Out:
# {'max_depth': 12, 'min_samples_leaf': 4, 'n_estimators': 200}

# %%
reg = gs.best_estimator_

# %%
from sklearn.model_selection import cross_val_score
train_score = reg.score(X_train, y_train)
val_score = cross_val_score(reg, X_train, y_train, cv=5)
test_score = reg.score(X_test, y_test)
print('Train score', train_score)
print('Validation score', val_score)
print('Test score', test_score)
# Out:
# Train score 0.8236576874151806
# Validation score [0.66168203 0.68175502 0.66840391 0.65741499 0.60545505]
# Test score 0.6649300054807341
